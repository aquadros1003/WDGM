# %%
import GrayScaleTransform

img_arr = GrayScaleTransform.GrayScaleTransform('D:\STUDIES\WDGM\WDGM\lab2\lena.jpg')
rgb_data = img_arr.data


img_arr.to_gray()
img_arr.show_img()
data_gray = img_arr.data  
print(data_gray.shape)
# Out:
# (512, 512)

# %%
import GrayScaleTransform
import matplotlib.pyplot as plt

img_arr = GrayScaleTransform.GrayScaleTransform('D:\STUDIES\WDGM\WDGM\lab2\lena.jpg')
img_arr.to_sepia((1.8, 0.2))
data = img_arr.data
img_arr.show_img()
print(data.shape)
# Out:
# (512, 512, 3)
