# %%
import Histogram as hist
from Image import *

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")

data = img_arr.data
img_arr.show_img()

# %%
from Image import *
import Histogram as hist

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")
img_arr.to_gray()
histogram = hist.Histogram(img_arr.data)
histogram.to_cumulated().plot()

# %%
import Histogram as hist
from Image import *


img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")
img_arr.to_gray()
img_arr.show_img()

# %%
import Histogram as hist
from Image import * 

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\papyka.jpg")
hist = hist.Histogram(img_arr.data)
hist.to_cumulated().plot()

# %%
from Image import Image
import matplotlib.pyplot as plt

img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr.to_gray()
data1_gray = img_arr.data
img_arr1 = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr1.to_gray()
img_arr1.align_image(False)
data2_gray = img_arr1.data
img_arr2 = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr2.to_gray()
img_arr2.align_image(True)
data3_gray = img_arr2.data

f, ax_arr = plt.subplots(1, 3, figsize=(15, 5))
ax_arr[0].imshow(data1_gray, cmap='gray')
ax_arr[0].set_title("GRAY")
ax_arr[0].axis("off")
ax_arr[1].imshow(data2_gray, cmap='gray')
ax_arr[1]. set_title("GRAY WITH EQUALIZATION")
ax_arr[1].axis("off")
ax_arr[2].imshow(data3_gray, cmap='gray')
ax_arr[2].set_title("GRAY WITH EQUALIZATION AND TAIL REMOWING")
ax_arr[2].axis("off")
plt.show()

# %%
from Image import Image
from Histogram import Histogram
img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr.to_gray()
histogram = Histogram(img_arr.data)
hist_data0 = histogram.values[0]
histogram.plot()

# %%
from Image import Image
from Histogram import Histogram
img_arr1 = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr1.to_gray()
img_arr1.align_image(False)
histogram = Histogram(img_arr1.data)
histogram.plot()

# %%
from Image import Image
from Histogram import Histogram
img_arr2 = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr2.to_gray()
img_arr2.align_image(True)
histogram = Histogram(img_arr2.data)
histogram.plot()

# %%
from Image import Image
import matplotlib.pyplot as plt

img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
data1 = img_arr.data
img_arr1 = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr1.align_image(False)
data2 = img_arr1.data
img_arr2 = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr2.align_image(True)
data3 = img_arr2.data


f, ax_arr = plt.subplots(1, 3, figsize=(15, 5))
ax_arr[0].imshow(data1)
ax_arr[0].set_title("RGB")
ax_arr[0].axis("off")
ax_arr[1].imshow(data2)
ax_arr[1]. set_title("RGB WITH EQUALIZATION")
ax_arr[1].axis("off")
ax_arr[2].imshow(data3)
ax_arr[2].set_title("RGB WITH EQUALIZATION AND TAIL REMOWING")
ax_arr[2].axis("off")
plt.show()

# %%
from Image import Image
from Histogram import Histogram
img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
histogram = Histogram(img_arr.data)
histogram.plot()

# %%
from Image import Image
from Histogram import Histogram
img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr.align_image(False)
histogram = Histogram(img_arr.data)
histogram.plot()

# %%
from Image import Image
from Histogram import Histogram
img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr.align_image(True)
histogram = Histogram(img_arr.data)
histogram.plot()

# %%
from Image import Image
import matplotlib.pyplot as plt

img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\pluca.jpg')
data1_gray = img_arr.data
img_arr1 = Image('D:\STUDIES\WDGM\WDGM\lab5\pluca.jpg')
img_arr1.align_image(False)
data2_gray = img_arr1.data
img_arr2 = Image('D:\STUDIES\WDGM\WDGM\lab5\pluca.jpg')
img_arr2.align_image(True)
data3_gray = img_arr2.data

f, ax_arr = plt.subplots(1, 3, figsize=(15, 5))
ax_arr[0].imshow(data1_gray, cmap='gray')
ax_arr[0].set_title("GRAY")
ax_arr[0].axis("off")
ax_arr[1].imshow(data2_gray, cmap='gray')
ax_arr[1]. set_title("GRAY WITH EQUALIZATION")
ax_arr[1].axis("off")
ax_arr[2].imshow(data3_gray, cmap='gray')
ax_arr[2].set_title("GRAY WITH EQUALIZATION AND TAIL REMOWING")
ax_arr[2].axis("off")
plt.show()

# %%
from Image import Image
import matplotlib.pyplot as plt

img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\oko.jpeg')
data1_gray = img_arr.data
img_arr1 = Image('D:\STUDIES\WDGM\WDGM\lab5\oko.jpeg')
img_arr1.align_image(False)
data2_gray = img_arr1.data
img_arr2 = Image('D:\STUDIES\WDGM\WDGM\lab5\oko.jpeg')
img_arr2.align_image(True)
data3_gray = img_arr2.data

f, ax_arr = plt.subplots(1, 3, figsize=(15, 5))
ax_arr[0].imshow(data1_gray, cmap='gray')
ax_arr[0].set_title("RGB")
ax_arr[0].axis("off")
ax_arr[1].imshow(data2_gray, cmap='gray')
ax_arr[1]. set_title("RGB WITH EQUALIZATION")
ax_arr[1].axis("off")
ax_arr[2].imshow(data3_gray, cmap='gray')
ax_arr[2].set_title("RGB WITH EQUALIZATION AND TAIL REMOWING")
ax_arr[2].axis("off")
plt.show()

# %%
from Image import Image
import matplotlib.pyplot as plt

img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\papyka.jpg')
data1_gray = img_arr.data
img_arr1 = Image('D:\STUDIES\WDGM\WDGM\lab5\papyka.jpg')
img_arr1.align_image(False)
data2_gray = img_arr1.data
img_arr2 = Image('D:\STUDIES\WDGM\WDGM\lab5\papyka.jpg')
img_arr2.align_image(True)
data3_gray = img_arr2.data

f, ax_arr = plt.subplots(1, 3, figsize=(15, 5))
ax_arr[0].imshow(data1_gray, cmap='gray')
ax_arr[0].set_title("GRAY")
ax_arr[0].axis("off")
ax_arr[1].imshow(data2_gray, cmap='gray')
ax_arr[1]. set_title("GRAY WITH EQUALIZATION")
ax_arr[1].axis("off")
ax_arr[2].imshow(data3_gray, cmap='gray')
ax_arr[2].set_title("GRAY WITH EQUALIZATION AND TAIL REMOWING")
ax_arr[2].axis("off")
plt.show()

# %%
from Image import Image
from Histogram import Histogram
img_arr = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr.to_gray()
histogram = Histogram(img_arr.data)
hist_data0 = histogram.values[0]
histogram.plot()

from Image import Image
from Histogram import Histogram
img_arr1 = Image('D:\STUDIES\WDGM\WDGM\lab5\lena.jpg')
img_arr1.to_gray()
img_arr1.align_image(False)
histogram = Histogram(img_arr1.data)
hist_data1 = histogram.values[0]
histogram.plot()
