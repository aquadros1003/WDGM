# %%
import Histogram as hist
from Image import *

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")

data = img_arr.data
histogram = hist.Histogram(img_arr.data)
histogram.plot()

# %%
from Image import *
import Histogram as hist

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")
img_arr.to_gray()
histogram = hist.Histogram(img_arr.data)
histogram.to_cumulated().plot()

# %%
import Histogram as hist
from Image import *


img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")
img_arr.to_gray()
histogram = hist.Histogram(img_arr.data)
histogram.plot()

# %%
import Histogram as hist
from Image import * 

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\papyka.jpg")
img_arr.to_gray()
data3 = img_arr.data
img_arr.align_image()
data4 = img_arr.data
histogram = hist.Histogram(img_arr.data)
histogram.plot()

# %%
img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")
print(img_arr.data.shape)
histogram = hist.Histogram(img_arr.data)
histogram.plot()
# Out:
# (512, 512, 3)

# %%
from Image import *
img_arr = Image("D:\STUDIES\WDGM\WDGM\lab5\lena.jpg")
img_arr2 = img_arr.align_image()
histogram2 = hist.Histogram(img_arr2.data)
histogram2.plot()
