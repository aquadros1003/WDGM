# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
print(img_arr.data.shape)
kernel = np.array([0, 0, 0, 0, 1, 0, 0, 0, 0]).reshape(3, 3)
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel)
img_arr.show_img()
# Out:
# (100, 100, 3)

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
kernel = np.array([0, -1, 0, -1, 5, -1, 0, -1, 0]).reshape(3, 3)
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
kernel = np.array([1, 1, 1, 1, 1, 1, 1, 1, 1]).reshape(3, 3)
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel, 1/9)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
kernel = np.array([1, 2, 1, 2, 4, 2, 1, 2, 1]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel, 1/16)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
kernel = np.array([1, 4, 6, 4, 1, 4, 16, 24, 16, 4, 6, 24, 36, 24, 6, 4, 16, 24, 16, 4, 1, 4, 6, 4, 1]).reshape((5, 5))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel, 1/256)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\Sudoku2.jpg")
img_arr.to_gray()
kernel = np.array([0, 1, 2, -1, 0, 1, -2, -1, 0]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\Sudoku2.jpg")
img_arr.to_gray()
kernel = np.array([1, 2, 1, 0, 0, 0, -1, -2, -1]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\Sudoku2.jpg")
img_arr.to_gray()
kernel = np.array([2, 1, 0, 1, 0, -1, 0, -1, -2]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
img_arr.to_gray()
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
img_arr.to_gray()
kernel = np.array([0, -1, 0, -1, 5, -1, 0, -1, 0]).reshape(3, 3)
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\identity.jpg")
img_arr.to_gray()
kernel = np.array([1, 2, 1, 2, 4, 2, 1, 2, 1]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel, 1/16)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\lena.jpg")
img_arr.to_gray()
kernel = np.array([1, 2, 1, 2, 4, 2, 1, 2, 1]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel, 1/16)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\lena.jpg")
img_arr.to_gray()
kernel = np.array([1, 1, 1, 1, 1,1 ,1 ,1, 1]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel, 1/9)
img_arr.show_img()

# %%
from ImageFiltration import *
from Image import *
import numpy as np

img_arr = Image("D:\STUDIES\WDGM\WDGM\lab6\lena.jpg")
img_arr.to_gray()
kernel = np.array([0, -1, 0, -1, 5, -1, 0, -1, 0]).reshape((3, 3))
filtr = ImageFiltration()
filtr.conv_2d(img_arr, kernel, 1/9)
img_arr.show_img()
