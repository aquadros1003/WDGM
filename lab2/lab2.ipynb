# %%
from BaseImage import BaseImage
import matplotlib.pyplot as plt

img_arr = BaseImage('D:\STUDIES\WDGM\WDGM\lab2\lena.jpg')
base_data = img_arr.data
img_arr.to_hsv()
hsv_data = img_arr.data
img_arr.to_rgb()
rgb_from_hsv = img_arr.data

f, ax_arr = plt.subplots(1, 2)
ax_arr[0].imshow(base_data)
ax_arr[0].set_title("RGB")
ax_arr[0].axis("off")
ax_arr[1].imshow(rgb_from_hsv)
ax_arr[1]. set_title("RGB_FROM_HSV")
ax_arr[1].axis("off")
plt.show()

# %%
from BaseImage import BaseImage
import matplotlib.pyplot as plt

img_arr = BaseImage('D:\STUDIES\WDGM\WDGM\lab2\lena.jpg')
base_data = img_arr.data
img_arr.to_hsi()
hsi_data = img_arr.data
img_arr.to_rgb()
rgb_from_hsi = img_arr.data

f, ax_arr = plt.subplots(1, 2)
ax_arr[0].imshow(base_data)
ax_arr[0].set_title("RGB")
ax_arr[0].axis("off")
ax_arr[1].imshow(rgb_from_hsi)
ax_arr[1]. set_title("RGB_FROM_HSI")
ax_arr[1].axis("off")
plt.show()

img_arr.save_img('D:\STUDIES\WDGM\WDGM\lab2\lena_hsv.jpg')

# %%
from BaseImage import BaseImage
import matplotlib.pyplot as plt

img_arr = BaseImage('D:\STUDIES\WDGM\WDGM\lab2\lena.jpg')
base_data = img_arr.data
img_arr.to_hsl()
hsl_data = img_arr.data
img_arr.to_rgb()
rgb_from_hsl = img_arr.data

f, ax_arr = plt.subplots(1, 2)
ax_arr[0].imshow(base_data)
ax_arr[0].set_title("RGB")
ax_arr[0].axis("off")
ax_arr[1].imshow(rgb_from_hsl)
ax_arr[1]. set_title("RGB_FROM_HSL")
ax_arr[1].axis("off")
plt.show()

# %%
from BaseImage import BaseImage
import matplotlib.pyplot as plt

img_arr = BaseImage('D:\STUDIES\WDGM\WDGM\lab2\gfp.jpg')
img_arr1 = BaseImage('D:\STUDIES\WDGM\WDGM\lab2\gfp.jpg')
img_arr2 = BaseImage('D:\STUDIES\WDGM\WDGM\lab2\gfp.jpg')

#1
base_data = img_arr.data
img_arr.to_hsv()
hsv_data = img_arr.data
img_arr.to_rgb()
rgb_from_hsv = img_arr.data
#2
base_data1 = img_arr1.data
img_arr1.to_hsi()
hsi_data = img_arr1.data
img_arr1.to_rgb()
rgb_from_hsi = img_arr1.data
#3
base_data2 = img_arr2.data
img_arr2.to_hsl()
hsl_data = img_arr2.data
img_arr2.to_rgb()
rgb_from_hsl = img_arr2.data

f, ax_arr = plt.subplots(3, 2)
ax_arr[0, 0].imshow(base_data)
ax_arr[0, 0].set_title("RGB")
ax_arr[0, 0].axis("off")

ax_arr[0, 1].imshow(rgb_from_hsl)
ax_arr[0, 1]. set_title("RGB_FROM_HSV")
ax_arr[0, 1].axis("off")

ax_arr[1, 0].imshow(base_data1)
ax_arr[1, 0].set_title("RGB")
ax_arr[1, 0].axis("off")

ax_arr[1, 1].imshow(rgb_from_hsi)
ax_arr[1, 1]. set_title("RGB_FROM_HSI")
ax_arr[1, 1].axis("off")

ax_arr[2, 0].imshow(base_data2)
ax_arr[2, 0].set_title("RGB")
ax_arr[2, 0].axis("off")

ax_arr[2, 1].imshow(rgb_from_hsl)
ax_arr[2, 1]. set_title("RGB_FROM_HSL")
ax_arr[2, 1].axis("off")
plt.show()
