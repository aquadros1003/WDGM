# %%
import GrayScaleTransform as gst
import Histogram as hist

img_arr = gst.GrayScaleTransform("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")

img_arr.to_gray()
data = img_arr.data
histogram = hist.Histogram(img_arr.data)
histogram.plot()

# %%
import GrayScaleTransform as gst
import Histogram as hist

img_arr = gst.GrayScaleTransform("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")

data = img_arr.data
histogram = hist.Histogram(img_arr.data)
histogram.plot()

# %%
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr.show_img()

# %%
from ImageComparison import ImageComparison
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\papyka.jpg")
img_arr2.show_img()

# %%
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\papyka.jpg")

img_arr.histogram().plot()
img_arr2.histogram().plot()

# %%
import GrayScaleTransform as gst
import Histogram as hist
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\papyka.jpg")
img_arr.to_gray()
img_arr2.to_gray()
img_arr.histogram().plot()
img_arr2.histogram().plot()

# %%
import GrayScaleTransform as gst
import Histogram as hist
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\papyka.jpg")
img_arr.to_gray()
img_arr2.to_gray()
similarity = img_arr.compare_to(img_arr2, 0)
print(similarity)
similarity = img_arr.compare_to(img_arr2, 1)
print(similarity)
# Out:
# 64852344.0
# 8053.0953055331465

# %%
import GrayScaleTransform as gst
import Histogram as hist
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena_hsv.jpg")
img_arr.to_gray()
img_arr2.to_gray()
img_arr.histogram().plot()
img_arr2.histogram().plot()

# %%
import GrayScaleTransform as gst
import Histogram as hist
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena_hsv.jpg")
img_arr.to_gray()
img_arr2.to_gray()
similarity = img_arr.compare_to(img_arr2, 0)
print(similarity)
similarity = img_arr.compare_to(img_arr2, 1)
print(similarity)
print(img_arr.compare_to_percent(img_arr2))
# Out:
# 1819049.0
# 1348.7212462180612
# 86.51

# %%
import GrayScaleTransform as gst
import Histogram as hist
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena2.jpg")
img_arr.to_gray()
img_arr2.to_gray()
similarity = img_arr.compare_to(img_arr2, 0)
print(similarity)
similarity = img_arr.compare_to(img_arr2, 1)
print(similarity)
print(img_arr.compare_to_percent(img_arr2))
# Out:
# 0.0
# 0.0
# 100.0

# %%
import GrayScaleTransform as gst
import Histogram as hist
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena_hsi.jpg")
img_arr.to_gray()
img_arr2.to_gray()
similarity = img_arr.compare_to(img_arr2, 0)
print(similarity)
similarity = img_arr.compare_to(img_arr2, 1)
print(similarity)
print(img_arr.compare_to_percent(img_arr2))
# Out:
# 21966004.0
# 4686.790372952475
# 53.13

# %%
import GrayScaleTransform as gst
import Histogram as hist
from ImageComparison import ImageComparison

img_arr = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena.jpg")
img_arr2 = ImageComparison("D:\STUDIES\WDGM\WDGM\lab4\lena_hsl.jpg")
img_arr.to_gray()
img_arr2.to_gray()
similarity = img_arr.compare_to(img_arr2, 0)
print(similarity)
similarity = img_arr.compare_to(img_arr2, 1)
print(similarity)
print(img_arr.compare_to_percent(img_arr2))
# Out:
# 1359578.0
# 1166.0094339241
# 88.34
